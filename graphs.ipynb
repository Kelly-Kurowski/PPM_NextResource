# %% [markdown]
# BPIC 2013 graphs: Encoding comparison for each model

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

from matplotlib.font_manager import fontManager

# Data for BPIC2013 LightGBM
prefixes = [10, 20, 30, 40, 50, 75, 100, 125, 150]

accuracy_encoding_1 = [0.7000, 0.6700, 0.6750, 0.6471, 0.6610, 0.6667, 0.7222, 0.5667, 0.5417]
accuracy_encoding_2 = [0.6786, 0.6900, 0.6750, 0.6471, 0.6610, 0.6667, 0.7222, 0.5667, 0.5417]
accuracy_encoding_3 = [0.9714, 0.8200, 0.7750, 0.6912, 0.7458, 0.6222, 0.6944, 0.6333, 0.5833]
accuracy_encoding_4 = [0.9635, 0.8400, 0.7750, 0.6912, 0.7288, 0.6552, 0.6944, 0.5357, 0.5833]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Baseline - SeqOnly"] * len(prefixes) + ["SCap"] * len(prefixes) +
                ["S2g"] * len(prefixes) + ["S2gR"] * len(prefixes)
})

# Plot
plt.figure(figsize=(16, 12))  # Match larger figure size

# Lineplot with styling
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and axes
plt.title("LightGBM", fontsize=24)
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)
plt.ylim(0, 1)
plt.grid(True)

# Custom ticks
plt.xticks(ticks=prefixes, fontsize=20)
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Legend formatting
plt.legend(loc="upper center", bbox_to_anchor=(0.4, -0.2), ncol=4, fontsize=21)

# Adjust subplot for spacing
plt.subplots_adjust(bottom=0.2)

# Save as SVG
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2013_LightGBM_final.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2013_LightGBM_final.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data BPIC2013 Random Forrest
prefixes = [10, 20, 30, 40, 50, 75, 100, 125, 150]

accuracy_encoding_1 = [0.7143, 0.6700, 0.7125, 0.6765, 0.6780, 0.6889, 0.6944, 0.6333, 0.5417]
accuracy_encoding_2 = [0.7071, 0.6700, 0.7125, 0.6618, 0.6780, 0.6889, 0.6944, 0.6667, 0.5833]
accuracy_encoding_3 = [0.9429, 0.7400, 0.6875, 0.6471, 0.7119, 0.6444, 0.6944, 0.6667, 0.6250]
accuracy_encoding_4 = [0.9357, 0.8300, 0.7000, 0.6912, 0.7797, 0.6776, 0.6944, 0.6841, 0.6667]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Match larger figure size
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o")

# Title and axes
plt.title("Random Forest", fontsize=24)
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)
plt.ylim(0, 1)
plt.grid(True)

# Custom ticks
plt.xticks(ticks=prefixes, fontsize=20)
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Legend formatting
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot for spacing
plt.subplots_adjust(bottom=0.2)

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2013_RF_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2013_RF_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data BPIC2013 LSTM
prefixes = [10, 20, 30, 40, 50, 75, 100, 125, 150]

accuracy_encoding_1 = [0.7087, 0.6809, 0.6899, 0.6803, 0.6854, 0.6781, 0.7044, 0.7094, 0.5959]
accuracy_encoding_2 = [0.7068, 0.6835, 0.6867, 0.6803, 0.6767, 0.6781, 0.7044, 0.7007, 0.6064]
accuracy_encoding_3 = [0.9874, 0.9272, 0.6613, 0.6697, 0.7151, 0.6551, 0.7042, 0.6667, 0.6064]
accuracy_encoding_4 = [0.9748, 0.9599, 0.7058, 0.6879, 0.7151, 0.6610, 0.7113, 0.6667, 0.6064]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Match larger figure size
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o")

# Title and axes
plt.title("LSTM", fontsize=24)
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)
plt.ylim(0, 1)
plt.grid(True)

# Custom ticks
plt.xticks(ticks=prefixes, fontsize=20)
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Legend formatting
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot for spacing
plt.subplots_adjust(bottom=0.2)

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2013_LSTM_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2013_LSTM_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data BPIC2013 Transformer
prefixes = [10, 20, 30, 40, 50, 75, 100, 125, 150]

accuracy_encoding_1 = [0.7143, 0.6900, 0.6500, 0.5735, 0.6271, 0.4839, 0.6667, 0.5000, 0.3750]
accuracy_encoding_2 = [0.7286, 0.6600, 0.6000, 0.6471, 0.5763, 0.4889, 0.6389, 0.4333, 0.5000]
accuracy_encoding_3 = [0.9500, 0.7000, 0.6000, 0.5735, 0.5424, 0.6444, 0.6667, 0.6000, 0.3750]
accuracy_encoding_4 = [0.8643, 0.6700, 0.5250, 0.6324, 0.6949, 0.6889, 0.6944, 0.5667, 0.6250]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Match larger figure size
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o")

# Title and axes
plt.title("Transformer", fontsize=24)
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)
plt.ylim(0, 1)
plt.grid(True)

# Custom ticks
plt.xticks(ticks=prefixes, fontsize=20)
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Legend formatting
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot for spacing
plt.subplots_adjust(bottom=0.2)

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/ccuracy_plot_2013_TF_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/ccuracy_plot_2013_TF_fixed.svg

# %% [markdown]
# BPIC 2017 graphs: Encoding comparison for each model

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for BPIC2017 Random Forest
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000]

accuracy_encoding_1 = [
    0.5862, 0.4286, 0.5714, 0.4074, 0.4444, 0.5000, 0.5200, 0.5600, 0.3333, 0.4348, 0.2857
]
accuracy_encoding_2 = [
    0.5862, 0.4286, 0.5000, 0.4444, 0.5185, 0.4231, 0.4800, 0.5600, 0.3333, 0.4348, 0.3333
]
accuracy_encoding_3 = [
    0.6897, 0.6786, 0.6786, 0.5556, 0.5556, 0.6538, 0.7200, 0.5600, 0.5833, 0.7391, 0.6190
]
accuracy_encoding_4 = [
    0.6207, 0.5714, 0.6786, 0.5556, 0.6296, 0.6923, 0.7200, 0.6800, 0.6667, 0.6957, 0.6190
]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) + 
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Random Forest", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to avoid clutter (showing only the key prefixes)
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=50)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/random_forest_accuracy_plot_2017_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/random_forest_accuracy_plot_2017_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for LightGBM BPIC2017
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000]

accuracy_encoding_1 = [
    0.6897, 0.5000, 0.4286, 0.4074, 0.4444, 0.5000, 0.5600, 0.5200, 0.2500, 0.3913, 0.3810
]
accuracy_encoding_2 = [
    0.6552, 0.4286, 0.4286, 0.3704, 0.4815, 0.4615, 0.5200, 0.5200, 0.2917, 0.3913, 0.3810
]
accuracy_encoding_3 = [
    0.6552, 0.7143, 0.6786, 0.4815, 0.6296, 0.6154, 0.6800, 0.6800, 0.6250, 0.6087, 0.5238
]
accuracy_encoding_4 = [
    0.5862, 0.6786, 0.7143, 0.4815, 0.7037, 0.6154, 0.8000, 0.6800, 0.6250, 0.5652, 0.6190
]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) + 
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LightGBM", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=50)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2017_LightGBM_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2017_LightGBM_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for Prefixes (starting from 100) for LSTM BPIC2017
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000]

# Accuracy data for each encoding
accuracy_encoding_1 = [
    0.4107, 0.2909, 0.3636, 0.3606, 0.4314, 0.3267, 0.3037, 0.3763, 0.3661, 0.3409, 0.2412
]
accuracy_encoding_2 = [
    0.3403, 0.2545, 0.2909, 0.2684, 0.2971, 0.2971, 0.2421, 0.3763, 0.2152, 0.3088, 0.2162
]
accuracy_encoding_3 = [
    0.3846, 0.3273, 0.3182, 0.4182, 0.3938, 0.3171, 0.3837, 0.5205, 0.3450, 0.3620, 0.2419
]
accuracy_encoding_4 = [
    0.4648, 0.4000, 0.3909, 0.3623, 0.4148, 0.3752, 0.3837, 0.5205, 0.3123, 0.3520, 0.2287
]

# Create DataFrame
df = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) + 
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LSTM", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=50)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2017_LSTM_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2017_LSTM_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for Prefixes (starting from 100)
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000]

# Accuracy data for each encoding (Transformer)
accuracy_encoding_1_Transformer = [
    0.3793, 0.3929, 0.3929, 0.2222, 0.4444, 0.2692, 0.3600, 0.5200, 0.2500, 0.4091, 0.5238
]
accuracy_encoding_2_Transformer = [
    0.4828, 0.3929, 0.3571, 0.3704, 0.2222, 0.4231, 0.3200, 0.4400, 0.3750, 0.2174, 0.3333
]
accuracy_encoding_3_Transformer = [
    0.5862, 0.4286, 0.5714, 0.7778, 0.5556, 0.6923, 0.5200, 0.6800, 0.6667, 0.7826, 0.5238
]
accuracy_encoding_4_Transformer = [
    0.5172, 0.3214, 0.3214, 0.3704, 0.3704, 0.4231, 0.3600, 0.2400, 0.5000, 0.2609, 0.4286
]

# Create DataFrame
df_Transformer = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1_Transformer + accuracy_encoding_2_Transformer + accuracy_encoding_3_Transformer + accuracy_encoding_4_Transformer,
    "Encoding": ["Encoding 1 (Transformer)"] * len(prefixes) + ["Encoding 2 (Transformer)"] * len(prefixes) + 
                ["Encoding 3 (Transformer)"] * len(prefixes) + ["Encoding 4 (Transformer)"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_Transformer, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Transformer", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=50)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2017_TF_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()

plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2017_TF_fixed.svg

# %% [markdown]
# BPIC 2018 graphs: Encoding comparison for each model

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for LightGBM prefixes (starting from 100) BPIC2018
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500]

# New accuracy data for each encoding (LightGBM)
accuracy_encoding_1_LightGBM = [
    0.2903, 0.4516, 0.3333, 0.6207, 0.7143, 0.3704, 0.4444, 0.7600, 0.5417, 0.5417, 0.3913, 0.5000
]
accuracy_encoding_2_LightGBM = [
    0.3226, 0.4194, 0.3667, 0.6207, 0.6786, 0.3704, 0.4815, 0.7600, 0.5833, 0.5000, 0.3478, 0.4091
]
accuracy_encoding_3_LightGBM = [
    0.6897, 0.7500, 0.6429, 0.5556, 0.6667, 0.6154, 0.7200, 0.6400, 0.5833, 0.5652, 0.6190, 0.6500
]
accuracy_encoding_4_LightGBM = [
    0.4839, 0.6129, 0.4667, 0.4828, 0.6071, 0.4074, 0.5926, 0.5600, 0.5833, 0.6667, 0.4348, 0.5000
]

# Create DataFrame
df_LightGBM = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1_LightGBM + accuracy_encoding_2_LightGBM + accuracy_encoding_3_LightGBM + accuracy_encoding_4_LightGBM,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) + 
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_LightGBM, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LightGBM", fontsize=24)
plt.ylim(0, 1.0)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=60)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

plt.yticks(fontsize=20)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path = os.path.expanduser('~/Downloads/accuracy_plot_2018_LightGBM_fixed.svg')
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2018_LightGBM_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# New data for Random Forest prefixes (starting from 100) BPC2018
prefixes_rf = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500]

# Accuracy data for each encoding (Random Forest)
accuracy_encoding_1_rf = [
    0.3871, 0.4839, 0.5000, 0.5172, 0.4643, 0.4444, 0.5556, 0.5600, 0.6667, 0.5417, 0.3043, 0.4545
]
accuracy_encoding_2_rf = [
    0.3548, 0.4839, 0.5667, 0.4828, 0.5357, 0.4074, 0.4815, 0.5600, 0.6667, 0.5417, 0.3478, 0.4545
]
accuracy_encoding_3_rf = [
    0.4516, 0.6129, 0.6000, 0.5172, 0.6429, 0.4444, 0.6296, 0.5200, 0.5833, 0.6250, 0.4348, 0.5455
]
accuracy_encoding_4_rf = [
    0.6897, 0.6071, 0.6071, 0.6667, 0.5926, 0.6154, 0.7200, 0.6800, 0.7083, 0.6957, 0.6190, 0.6500
]

# Create DataFrame
df_rf = pd.DataFrame({
    "Prefix Length": prefixes_rf * 4,
    "Accuracy": accuracy_encoding_1_rf + accuracy_encoding_2_rf + accuracy_encoding_3_rf + accuracy_encoding_4_rf,
    "Encoding": ["Encoding 1 (Random Forest)"] * len(prefixes_rf) + ["Encoding 2 (Random Forest)"] * len(prefixes_rf) + 
                ["Encoding 3 (Random Forest)"] * len(prefixes_rf) + ["Encoding 4 (Random Forest)"] * len(prefixes_rf)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_rf, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Random Forest", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=60)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2018_RF_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

print(f"Plot saved to {download_path_rf}")
# Out:
# Plot saved to /Users/6706363/Downloads/accuracy_plot_2018_RF_fixed.svg

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import os

# Data for LSTM including 2500 prefix
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500]

accuracy_encoding_1 = [
    0.4717, 0.4957, 0.3917, 0.4530, 0.4561, 0.4528, 0.5333, 0.4700, 0.6000, 0.5158, 0.4497, 0.4471
]
accuracy_encoding_2 = [
    0.3577, 0.4140, 0.3750, 0.3913, 0.4296, 0.4255, 0.4762, 0.4389, 0.5158, 0.4842, 0.4268, 0.4353
]
accuracy_encoding_3 = [
    0.3747, 0.4133, 0.4167, 0.4427, 0.4640, 0.3887, 0.4190, 0.4579, 0.4842, 0.5053, 0.3706, 0.3765
]
accuracy_encoding_4 = [
    0.3733, 0.4300, 0.3833, 0.4340, 0.4466, 0.3606, 0.4190, 0.4900, 0.4842, 0.4731, 0.3712, 0.4235
]

# Create DataFrame
df_lstm = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_lstm, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LSTM", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=60)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2018_LSTM_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for Transformer including 2500 prefix
prefixes = [100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500]

accuracy_encoding_1 = [
    0.4516, 0.5806, 0.5333, 0.6207, 0.3929, 0.4074, 0.5185, 0.5200, 0.6250, 0.6250, 0.2174, 0.5000
]
accuracy_encoding_2 = [
    0.4516, 0.4839, 0.4667, 0.7241, 0.3929, 0.4074, 0.7037, 0.5600, 0.7083, 0.6667, 0.3913, 0.4545
]
accuracy_encoding_3 = [
    0.5161, 0.5161, 0.5333, 0.6897, 0.6071, 0.3704, 0.6667, 0.6400, 0.5417, 0.5417, 0.5217, 0.5000
]
accuracy_encoding_4 = [
    0.6452, 0.4839, 0.5000, 0.7586, 0.5714, 0.4444, 0.5926, 0.6000, 0.7500, 0.7083, 0.3913, 0.5000
]

# Create DataFrame
df_transformer = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_transformer, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Transformer", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 400, 600, 800, 1000, 1200, 1400, 1500, 2000, 2500], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=60)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2018_TF_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# BPIC 2019 graphs: Encoding comparison for each model

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for LightGBM BPIC2019
prefixes = [100, 150, 200, 300, 400, 500, 600, 700, 800]

accuracy_encoding_1 = [
    0.8000, 0.9655, 0.9444, 0.9362, 0.9070, 0.8421, 0.9189, 0.9143, 0.7500
]
accuracy_encoding_2 = [
    0.8000, 0.9483, 0.9444, 0.9574, 0.8837, 0.8158, 0.9189, 0.9143, 0.7500
]
accuracy_encoding_3 = [
    0.8923, 0.8966, 0.8889, 0.9362, 0.9070, 0.9474, 0.8919, 0.9143, 0.9062
]
accuracy_encoding_4 = [
     0.8615, 0.9310, 0.9074, 0.9149, 0.9302, 0.8947, 0.9189, 0.9143, 0.9062
]

# Create DataFrame
df_lightgbm = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_lightgbm, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LightGBM", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)


# Adjust the x-axis ticks to show only the relevant prefixes starting from 10
plt.xticks(ticks=[100, 150, 200, 300, 400, 500, 600, 700, 800], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2019_LightGBM_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for Random Forest BPIC2019
prefixes = [100, 150, 200, 300, 400, 500, 600, 700, 800]

accuracy_encoding_1 = [
    0.8923, 0.9138, 0.8889, 0.9149, 0.8837, 0.8684, 0.8649, 0.8857, 0.8438
]
accuracy_encoding_2 = [
    0.8923, 0.9310, 0.8889, 0.8936, 0.9070, 0.8684, 0.8919, 0.8571, 0.8438
]
accuracy_encoding_3 = [
    0.8923, 0.9310, 0.8889, 0.9362, 0.9302, 0.9211, 0.8919, 0.9429, 0.9062
]
accuracy_encoding_4 = [
    0.8462, 0.9310, 0.8889, 0.9362, 0.9302, 0.8947, 0.9189, 0.9143, 0.9062
]

# Create DataFrame
df_random_forest = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_random_forest, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Random Forest", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 300, 400, 500, 600, 700, 800], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2019_RF_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for LSTM BPIC2019
prefixes = [100, 150, 200, 300, 400, 500, 600, 700, 800]

accuracy_encoding_1 = [
    0.8103, 0.7454, 0.7171, 0.7065, 0.7139, 0.7015, 0.7781, 0.7201, 0.6985
]
accuracy_encoding_2 = [
    0.7121, 0.6383, 0.6264, 0.6904, 0.6251, 0.4890, 0.6190, 0.5749, 0.4905
]
accuracy_encoding_3 = [
    0.6202, 0.6595, 0.6606, 0.6523, 0.6242, 0.6230, 0.6879, 0.6693, 0.6378
]
accuracy_encoding_4 = [
    0.6125, 0.6596, 0.6745, 0.6467, 0.6428, 0.6292, 0.6670, 0.6328, 0.6372
]

# Create DataFrame
df_lstm = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_lstm, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("LSTM", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 300, 400, 500, 600, 700, 800], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

# Save the plot as SVG in the Downloads folder
download_path_rf = os.path.expanduser('~/Downloads/accuracy_plot_2019_LSTM_fixed.svg')
plt.savefig(download_path_rf, format='svg')

# Show plot
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Data for Transformer model BPIC2019
prefixes = [100, 150, 200, 300, 400, 500, 600, 700, 800]

accuracy_encoding_1 = [
    0.9385, 0.8966, 0.8704, 0.8723, 0.8837, 0.8421, 0.9189, 0.8857, 0.8750
]
accuracy_encoding_2 = [
    0.9538, 0.8966, 0.8519, 0.8936,  0.9070, 0.8421, 0.8919, 0.8857, 0.8750
]
accuracy_encoding_3 = [
    0.9231, 0.8621, 0.8889, 0.9362, 0.9070, 0.8684, 0.9189, 0.9143, 0.9062
]
accuracy_encoding_4 = [
    0.9385, 0.9138, 0.9074, 0.8936, 0.9302, 0.8947, 0.9459, 0.9429, 0.9062
]

# Create DataFrame
df_transformer = pd.DataFrame({
    "Prefix Length": prefixes * 4,
    "Accuracy": accuracy_encoding_1 + accuracy_encoding_2 + accuracy_encoding_3 + accuracy_encoding_4,
    "Encoding": ["Encoding 1"] * len(prefixes) + ["Encoding 2"] * len(prefixes) +
                ["Encoding 3"] * len(prefixes) + ["Encoding 4"] * len(prefixes)
})

# Plot
plt.figure(figsize=(12, 8))  # Increased figure size for better readability

# Plot with normal scaling for x-axis, make lines a bit thicker for better visibility
sns.lineplot(data=df_transformer, x="Prefix Length", y="Accuracy", hue="Encoding", marker="o", linewidth=2)

# Title and grid
plt.title("Transformer", fontsize=24)
plt.ylim(0, 1)  # Limit the y-axis to focus on the accuracy range
plt.grid(True)

# Adjust the x-axis ticks to show only the relevant prefixes starting from 100
plt.xticks(ticks=[100, 150, 200, 300, 400, 500, 600, 700, 800], fontsize=20)

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45)

plt.yticks(fontsize=20)

# Adjust the font size for the labels and legend to fit better
plt.xlabel("Prefix Length", fontsize=22)
plt.ylabel("Accuracy", fontsize=22, labelpad=10)

# Place legend below the plot, further adjusted to prevent overlap
plt.legend(loc="upper center", bbox_to_anchor=(0.5, -0.2), ncol=4, fontsize=12)

# Adjust subplot to avoid clipping the legend and axis
plt.subplots_adjust(bottom=0.15)  # Increased bottom margin for the legend

download_path = os.path.expanduser('~/Downloads/accuracy_plot_2019_TF_fixed.svg')
# Save the plot as SVG in the Downloads folder
plt.savefig(download_path, format='svg')

# Show plot
plt.tight_layout()
plt.show()
